# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)

# %%
def load_mtx(mtx_path: str, barcodes_path: str, features_path: str, sample_name: str | None = None) -> ad.AnnData:
    adata = sc.read_mtx(mtx_path).transpose()
    
    barcodes = pd.read_csv(barcodes_path, header=None, sep='\t', names=['barcodes'])
    features = pd.read_csv(features_path, header=None, sep='\t', names=['gene_ids', 'gene_names'])

    adata.obs_names = sample_name + "_" + barcodes['barcodes'] if sample_name is not None else barcodes['barcodes']
    adata.var_names = features['gene_ids']
    adata.var['gene_names'] = features['gene_names'].values
    
    if sample_name is not None:
        adata.obs['sample'] = sample_name

    return adata

# %%
data_path = "/nfs/data/COST_IBD/data/atopic_dermatitis/datasets/Gao"
sample_names = os.listdir(data_path)

# %%
adata_list = []

for sample_name in tqdm(sample_names):
    sample_dir = os.path.join(data_path, sample_name)

    matrix_path = os.path.join(sample_dir, "matrix.mtx.gz")
    barcodes_path = os.path.join(sample_dir, "barcodes.tsv.gz")
    features_path = os.path.join(sample_dir, "features.tsv.gz")

    single_adata: ad.AnnData = load_mtx(matrix_path, barcodes_path, features_path, sample_name)
    
    # The contents of gene_names are worthless
    single_adata.var.drop(columns=["gene_names"], inplace=True)

    # The dataset contains duplicated gene names
    single_adata.var_names_make_unique()

    adata_list.append(single_adata)
# Out:
# 100%|██████████| 4/4 [01:44<00:00, 26.25s/it]

# %%
adata = ad.concat(adata_list, join="outer")
adata
# Out:
# AnnData object with n_obs × n_vars = 35890 × 36601
#     obs: 'sample'

# %%
adata.write('/nfs/data/COST_IBD/data/atopic_dermatitis/anndata/Gao.h5ad')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 35890 × 36601
#     obs: 'sample'

# %%
adata = sc.read('/nfs/data/COST_IBD/data/atopic_dermatitis/anndata/Gao.h5ad')

# %%
adata.obs['patient'] = adata.obs['sample']
adata.obs.head()
# Out:
#                         sample patient             tissue        condition  \
# barcodes
# Con4_AAACCTGAGAAGCCCA-1   Con4    Con4  heparinized blood  healthy control
# Con4_AAACCTGAGAGAGCTC-1   Con4    Con4  heparinized blood  healthy control
# Con4_AAACCTGAGATAGCAT-1   Con4    Con4  heparinized blood  healthy control
# Con4_AAACCTGAGGGTCGAT-1   Con4    Con4  heparinized blood  healthy control
# Con4_AAACCTGAGTTATCGC-1   Con4    Con4  heparinized blood  healthy control
#
#                           cell_type                      batch
# barcodes
# Con4_AAACCTGAGAAGCCCA-1  PBMC cells  GSE230575_healthy control
# Con4_AAACCTGAGAGAGCTC-1  PBMC cells  GSE230575_healthy control
# Con4_AAACCTGAGATAGCAT-1  PBMC cells  GSE230575_healthy control
# Con4_AAACCTGAGGGTCGAT-1  PBMC cells  GSE230575_healthy control
# Con4_AAACCTGAGTTATCGC-1  PBMC cells  GSE230575_healthy control

# %%
adata.obs['tissue'] = 'heparinized blood'

# %%
def assign_condition(sample):
    if 'AD' in sample:
        return 'atopic dermatitis'
    elif 'Con' in sample:
        return 'healthy'
    else:
        return 'unknown'

adata.obs['condition'] = adata.obs['sample'].apply(assign_condition)

adata.obs.head()
# Out:
#                         sample patient             tissue condition  \
# barcodes
# Con4_AAACCTGAGAAGCCCA-1   Con4    Con4  heparinized blood   healthy
# Con4_AAACCTGAGAGAGCTC-1   Con4    Con4  heparinized blood   healthy
# Con4_AAACCTGAGATAGCAT-1   Con4    Con4  heparinized blood   healthy
# Con4_AAACCTGAGGGTCGAT-1   Con4    Con4  heparinized blood   healthy
# Con4_AAACCTGAGTTATCGC-1   Con4    Con4  heparinized blood   healthy
#
#                           cell_type                      batch
# barcodes
# Con4_AAACCTGAGAAGCCCA-1  PBMC cells  GSE193096_healthy control
# Con4_AAACCTGAGAGAGCTC-1  PBMC cells  GSE193096_healthy control
# Con4_AAACCTGAGATAGCAT-1  PBMC cells  GSE193096_healthy control
# Con4_AAACCTGAGGGTCGAT-1  PBMC cells  GSE193096_healthy control
# Con4_AAACCTGAGTTATCGC-1  PBMC cells  GSE193096_healthy control

# %%
adata.obs['cell_type'] = 'PBMC cells'

# %%
adata.obs
# Out:
#                         sample patient             tissue          condition  \
# barcodes
# Con4_AAACCTGAGAAGCCCA-1   Con4    Con4  heparinized blood    healthy control
# Con4_AAACCTGAGAGAGCTC-1   Con4    Con4  heparinized blood    healthy control
# Con4_AAACCTGAGATAGCAT-1   Con4    Con4  heparinized blood    healthy control
# Con4_AAACCTGAGGGTCGAT-1   Con4    Con4  heparinized blood    healthy control
# Con4_AAACCTGAGTTATCGC-1   Con4    Con4  heparinized blood    healthy control
# ...                        ...     ...                ...                ...
# AD1_TTTGTCATCAGTTAGC-1     AD1     AD1  heparinized blood  atopic dermatitis
# AD1_TTTGTCATCCTTGGTC-1     AD1     AD1  heparinized blood  atopic dermatitis
# AD1_TTTGTCATCTCGCTTG-1     AD1     AD1  heparinized blood  atopic dermatitis
# AD1_TTTGTCATCTCTTGAT-1     AD1     AD1  heparinized blood  atopic dermatitis
# AD1_TTTGTCATCTTTACGT-1     AD1     AD1  heparinized blood  atopic dermatitis
#
#                           cell_type                        batch
# barcodes
# Con4_AAACCTGAGAAGCCCA-1  PBMC cells    GSE230575_healthy control
# Con4_AAACCTGAGAGAGCTC-1  PBMC cells    GSE230575_healthy control
# Con4_AAACCTGAGATAGCAT-1  PBMC cells    GSE230575_healthy control
# Con4_AAACCTGAGGGTCGAT-1  PBMC cells    GSE230575_healthy control
# Con4_AAACCTGAGTTATCGC-1  PBMC cells    GSE230575_healthy control
# ...                             ...                          ...
# AD1_TTTGTCATCAGTTAGC-1   PBMC cells  GSE230575_atopic dermatitis
# AD1_TTTGTCATCCTTGGTC-1   PBMC cells  GSE230575_atopic dermatitis
# AD1_TTTGTCATCTCGCTTG-1   PBMC cells  GSE230575_atopic dermatitis
# AD1_TTTGTCATCTCTTGAT-1   PBMC cells  GSE230575_atopic dermatitis
# AD1_TTTGTCATCTTTACGT-1   PBMC cells  GSE230575_atopic dermatitis
#
# [35890 rows x 6 columns]

# %%
adata.obs['condition'].unique()
# Out:
# array(['healthy control', 'atopic dermatitis'], dtype=object)

# %%
adata.obs['batch'] = 'GSE193096_' + adata.obs['condition']
adata.obs
# Out:
#                         sample patient             tissue          condition  \
# barcodes
# Con4_AAACCTGAGAAGCCCA-1   Con4    Con4  heparinized blood            healthy
# Con4_AAACCTGAGAGAGCTC-1   Con4    Con4  heparinized blood            healthy
# Con4_AAACCTGAGATAGCAT-1   Con4    Con4  heparinized blood            healthy
# Con4_AAACCTGAGGGTCGAT-1   Con4    Con4  heparinized blood            healthy
# Con4_AAACCTGAGTTATCGC-1   Con4    Con4  heparinized blood            healthy
# ...                        ...     ...                ...                ...
# AD1_TTTGTCATCAGTTAGC-1     AD1     AD1  heparinized blood  atopic dermatitis
# AD1_TTTGTCATCCTTGGTC-1     AD1     AD1  heparinized blood  atopic dermatitis
# AD1_TTTGTCATCTCGCTTG-1     AD1     AD1  heparinized blood  atopic dermatitis
# AD1_TTTGTCATCTCTTGAT-1     AD1     AD1  heparinized blood  atopic dermatitis
# AD1_TTTGTCATCTTTACGT-1     AD1     AD1  heparinized blood  atopic dermatitis
#
#                           cell_type                        batch
# barcodes
# Con4_AAACCTGAGAAGCCCA-1  PBMC cells            GSE193096_healthy
# Con4_AAACCTGAGAGAGCTC-1  PBMC cells            GSE193096_healthy
# Con4_AAACCTGAGATAGCAT-1  PBMC cells            GSE193096_healthy
# Con4_AAACCTGAGGGTCGAT-1  PBMC cells            GSE193096_healthy
# Con4_AAACCTGAGTTATCGC-1  PBMC cells            GSE193096_healthy
# ...                             ...                          ...
# AD1_TTTGTCATCAGTTAGC-1   PBMC cells  GSE193096_atopic dermatitis
# AD1_TTTGTCATCCTTGGTC-1   PBMC cells  GSE193096_atopic dermatitis
# AD1_TTTGTCATCTCGCTTG-1   PBMC cells  GSE193096_atopic dermatitis
# AD1_TTTGTCATCTCTTGAT-1   PBMC cells  GSE193096_atopic dermatitis
# AD1_TTTGTCATCTTTACGT-1   PBMC cells  GSE193096_atopic dermatitis
#
# [35890 rows x 6 columns]

# %%
adata.write('/nfs/data/COST_IBD/data/atopic_dermatitis/anndata/Gao.h5ad')

# %%
adata = sc.read('/nfs/data/COST_IBD/data/atopic_dermatitis/anndata/Gao.h5ad')

# %%
adata.obs
# Out:
#                         sample patient             tissue          condition  \
# barcodes
# Con4_AAACCTGAGAAGCCCA-1   Con4    Con4  heparinized blood    healthy control
# Con4_AAACCTGAGAGAGCTC-1   Con4    Con4  heparinized blood    healthy control
# Con4_AAACCTGAGATAGCAT-1   Con4    Con4  heparinized blood    healthy control
# Con4_AAACCTGAGGGTCGAT-1   Con4    Con4  heparinized blood    healthy control
# Con4_AAACCTGAGTTATCGC-1   Con4    Con4  heparinized blood    healthy control
# ...                        ...     ...                ...                ...
# AD1_TTTGTCATCAGTTAGC-1     AD1     AD1  heparinized blood  atopic dermatitis
# AD1_TTTGTCATCCTTGGTC-1     AD1     AD1  heparinized blood  atopic dermatitis
# AD1_TTTGTCATCTCGCTTG-1     AD1     AD1  heparinized blood  atopic dermatitis
# AD1_TTTGTCATCTCTTGAT-1     AD1     AD1  heparinized blood  atopic dermatitis
# AD1_TTTGTCATCTTTACGT-1     AD1     AD1  heparinized blood  atopic dermatitis
#
#                           cell_type                        batch
# barcodes
# Con4_AAACCTGAGAAGCCCA-1  PBMC cells    GSE193096_healthy control
# Con4_AAACCTGAGAGAGCTC-1  PBMC cells    GSE193096_healthy control
# Con4_AAACCTGAGATAGCAT-1  PBMC cells    GSE193096_healthy control
# Con4_AAACCTGAGGGTCGAT-1  PBMC cells    GSE193096_healthy control
# Con4_AAACCTGAGTTATCGC-1  PBMC cells    GSE193096_healthy control
# ...                             ...                          ...
# AD1_TTTGTCATCAGTTAGC-1   PBMC cells  GSE193096_atopic dermatitis
# AD1_TTTGTCATCCTTGGTC-1   PBMC cells  GSE193096_atopic dermatitis
# AD1_TTTGTCATCTCGCTTG-1   PBMC cells  GSE193096_atopic dermatitis
# AD1_TTTGTCATCTCTTGAT-1   PBMC cells  GSE193096_atopic dermatitis
# AD1_TTTGTCATCTTTACGT-1   PBMC cells  GSE193096_atopic dermatitis
#
# [35890 rows x 6 columns]

# %%
adata = sc.read('/nfs/data/COST_IBD/data/atopic_dermatitis/anndata/filtered/Gao_filtered.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 8622 × 36601
#     obs: 'batch', 'cell_type', 'condition', 'sex', 'patient', 'tissue', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb'
#     var: 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'

# %%
adata.obs
# Out:
#                         sample patient             tissue          condition  \
# barcodes
# Con4_AAACCTGAGAAGCCCA-1   Con4    Con4  heparinized blood            healthy
# Con4_AAACCTGAGAGAGCTC-1   Con4    Con4  heparinized blood            healthy
# Con4_AAACCTGAGATAGCAT-1   Con4    Con4  heparinized blood            healthy
# Con4_AAACCTGAGGGTCGAT-1   Con4    Con4  heparinized blood            healthy
# Con4_AAACCTGAGTTATCGC-1   Con4    Con4  heparinized blood            healthy
# ...                        ...     ...                ...                ...
# AD1_TTTGTCATCAGTTAGC-1     AD1     AD1  heparinized blood  atopic dermatitis
# AD1_TTTGTCATCCTTGGTC-1     AD1     AD1  heparinized blood  atopic dermatitis
# AD1_TTTGTCATCTCGCTTG-1     AD1     AD1  heparinized blood  atopic dermatitis
# AD1_TTTGTCATCTCTTGAT-1     AD1     AD1  heparinized blood  atopic dermatitis
# AD1_TTTGTCATCTTTACGT-1     AD1     AD1  heparinized blood  atopic dermatitis
#
#                           cell_type                        batch
# barcodes
# Con4_AAACCTGAGAAGCCCA-1  PBMC cells            GSE193096_healthy
# Con4_AAACCTGAGAGAGCTC-1  PBMC cells            GSE193096_healthy
# Con4_AAACCTGAGATAGCAT-1  PBMC cells            GSE193096_healthy
# Con4_AAACCTGAGGGTCGAT-1  PBMC cells            GSE193096_healthy
# Con4_AAACCTGAGTTATCGC-1  PBMC cells            GSE193096_healthy
# ...                             ...                          ...
# AD1_TTTGTCATCAGTTAGC-1   PBMC cells  GSE193096_atopic dermatitis
# AD1_TTTGTCATCCTTGGTC-1   PBMC cells  GSE193096_atopic dermatitis
# AD1_TTTGTCATCTCGCTTG-1   PBMC cells  GSE193096_atopic dermatitis
# AD1_TTTGTCATCTCTTGAT-1   PBMC cells  GSE193096_atopic dermatitis
# AD1_TTTGTCATCTTTACGT-1   PBMC cells  GSE193096_atopic dermatitis
#
# [35890 rows x 6 columns]

# %%
adata.obs['severity'] = 'unknown' 
adata.obs.loc[adata.obs['condition'] == 'healthy', 'severity'] = 'unknown_healthy'

# %%
adata.obs
# Out:
#                         sample patient             tissue          condition  \
# barcodes
# Con4_AAACCTGAGAAGCCCA-1   Con4    Con4  heparinized blood            healthy
# Con4_AAACCTGAGAGAGCTC-1   Con4    Con4  heparinized blood            healthy
# Con4_AAACCTGAGATAGCAT-1   Con4    Con4  heparinized blood            healthy
# Con4_AAACCTGAGGGTCGAT-1   Con4    Con4  heparinized blood            healthy
# Con4_AAACCTGAGTTATCGC-1   Con4    Con4  heparinized blood            healthy
# ...                        ...     ...                ...                ...
# AD1_TTTGTCATCAGTTAGC-1     AD1     AD1  heparinized blood  atopic dermatitis
# AD1_TTTGTCATCCTTGGTC-1     AD1     AD1  heparinized blood  atopic dermatitis
# AD1_TTTGTCATCTCGCTTG-1     AD1     AD1  heparinized blood  atopic dermatitis
# AD1_TTTGTCATCTCTTGAT-1     AD1     AD1  heparinized blood  atopic dermatitis
# AD1_TTTGTCATCTTTACGT-1     AD1     AD1  heparinized blood  atopic dermatitis
#
#                           cell_type                        batch  \
# barcodes
# Con4_AAACCTGAGAAGCCCA-1  PBMC cells            GSE193096_healthy
# Con4_AAACCTGAGAGAGCTC-1  PBMC cells            GSE193096_healthy
# Con4_AAACCTGAGATAGCAT-1  PBMC cells            GSE193096_healthy
# Con4_AAACCTGAGGGTCGAT-1  PBMC cells            GSE193096_healthy
# Con4_AAACCTGAGTTATCGC-1  PBMC cells            GSE193096_healthy
# ...                             ...                          ...
# AD1_TTTGTCATCAGTTAGC-1   PBMC cells  GSE193096_atopic dermatitis
# AD1_TTTGTCATCCTTGGTC-1   PBMC cells  GSE193096_atopic dermatitis
# AD1_TTTGTCATCTCGCTTG-1   PBMC cells  GSE193096_atopic dermatitis
# AD1_TTTGTCATCTCTTGAT-1   PBMC cells  GSE193096_atopic dermatitis
# AD1_TTTGTCATCTTTACGT-1   PBMC cells  GSE193096_atopic dermatitis
#
#                                 severity
# barcodes
# Con4_AAACCTGAGAAGCCCA-1  unknown_healthy
# Con4_AAACCTGAGAGAGCTC-1  unknown_healthy
# Con4_AAACCTGAGATAGCAT-1  unknown_healthy
# Con4_AAACCTGAGGGTCGAT-1  unknown_healthy
# Con4_AAACCTGAGTTATCGC-1  unknown_healthy
# ...                                  ...
# AD1_TTTGTCATCAGTTAGC-1           unknown
# AD1_TTTGTCATCCTTGGTC-1           unknown
# AD1_TTTGTCATCTCGCTTG-1           unknown
# AD1_TTTGTCATCTCTTGAT-1           unknown
# AD1_TTTGTCATCTTTACGT-1           unknown
#
# [35890 rows x 7 columns]
