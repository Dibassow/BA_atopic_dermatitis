# %%
import anndata as ad
import scanpy as sc
import pandas as pd
import os
import numpy as np
from tqdm import tqdm

# %%
import toolbox as tb

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)

# %%
def load_mtx(mtx_path: str, barcodes_path: str, features_path: str, sample_name: str | None = None) -> ad.AnnData:
    adata = sc.read_mtx(mtx_path).transpose()
    
    barcodes = pd.read_csv(barcodes_path, header=None, sep='\t', names=['barcodes'])
    features = pd.read_csv(features_path, header=None, sep='\t', names=['gene_ids', 'gene_names'])

    adata.obs_names = sample_name + "_" + barcodes['barcodes'] if sample_name is not None else barcodes['barcodes']
    adata.var_names = features['gene_ids']
    adata.var['gene_names'] = features['gene_names'].values
    
    if sample_name is not None:
        adata.obs['sample'] = sample_name

    return adata

# %%
data_path = "/nfs/data/COST_IBD/data/atopic_dermatitis/datasets/Rindler"
sample_names = os.listdir(data_path)

# %%
adata_list = []

for sample_name in tqdm(sample_names):
    sample_dir = os.path.join(data_path, sample_name)

    matrix_path = os.path.join(sample_dir, "matrix.mtx.gz")
    barcodes_path = os.path.join(sample_dir, "barcodes.tsv.gz")
    features_path = os.path.join(sample_dir, "features.tsv.gz")

    single_adata: ad.AnnData = load_mtx(matrix_path, barcodes_path, features_path, sample_name)
    
    # The contents of gene_names are worthless
    single_adata.var.drop(columns=["gene_names"], inplace=True)

    # The dataset contains duplicated gene names
    single_adata.var_names_make_unique()

    adata_list.append(single_adata)
# Out:
# 100%|██████████| 4/4 [00:07<00:00,  1.88s/it]

# %%
adata = ad.concat(adata_list, join="outer")
adata
# Out:
# AnnData object with n_obs × n_vars = 3598 × 33538
#     obs: 'sample'

# %%
adata.write('/nfs/data/COST_IBD/data/atopic_dermatitis/anndata/rindler.h5ad')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 3598 × 33538
#     obs: 'sample'

# %%
adata = sc.read('/nfs/data/COST_IBD/data/atopic_dermatitis/anndata/rindler.h5ad')

# %%
adata.obs
# Out:
#                         sample
# barcodes
# AD20_AAACCCAGTGTGTTTG-1   AD20
# AD20_AAACCCATCTCCCTAG-1   AD20
# AD20_AAACGAACATGGCGCT-1   AD20
# AD20_AAACGAATCACAGTGT-1   AD20
# AD20_AAACGCTCAGGATGAC-1   AD20
# ...                        ...
# AD24_TTTCGATAGCATACTC-1   AD24
# AD24_TTTGACTAGCATTTCG-1   AD24
# AD24_TTTGACTAGTGAATAC-1   AD24
# AD24_TTTGACTAGTTCATCG-1   AD24
# AD24_TTTGATCAGCTTCTAG-1   AD24
#
# [3598 rows x 1 columns]

# %%
adata.obs['patient'] = adata.obs['sample']
adata.obs.head()
# Out:
#                         sample patient
# barcodes
# AD20_AAACCCAGTGTGTTTG-1   AD20    AD20
# AD20_AAACCCATCTCCCTAG-1   AD20    AD20
# AD20_AAACGAACATGGCGCT-1   AD20    AD20
# AD20_AAACGAATCACAGTGT-1   AD20    AD20
# AD20_AAACGCTCAGGATGAC-1   AD20    AD20

# %%
adata.obs['tissue'] = 'Skin Suction Blister'
adata.obs
# Out:
#                         sample patient                tissue  \
# barcodes
# AD20_AAACCCAGTGTGTTTG-1   AD20    AD20  Skin Suction Blister
# AD20_AAACCCATCTCCCTAG-1   AD20    AD20  Skin Suction Blister
# AD20_AAACGAACATGGCGCT-1   AD20    AD20  Skin Suction Blister
# AD20_AAACGAATCACAGTGT-1   AD20    AD20  Skin Suction Blister
# AD20_AAACGCTCAGGATGAC-1   AD20    AD20  Skin Suction Blister
# ...                        ...     ...                   ...
# AD24_TTTCGATAGCATACTC-1   AD24    AD24  Skin Suction Blister
# AD24_TTTGACTAGCATTTCG-1   AD24    AD24  Skin Suction Blister
# AD24_TTTGACTAGTGAATAC-1   AD24    AD24  Skin Suction Blister
# AD24_TTTGACTAGTTCATCG-1   AD24    AD24  Skin Suction Blister
# AD24_TTTGATCAGCTTCTAG-1   AD24    AD24  Skin Suction Blister
#
#                                                       condition      batch  \
# barcodes
# AD20_AAACCCAGTGTGTTTG-1  Spontaneously healed atopic dermatitis  GSE162054
# AD20_AAACCCATCTCCCTAG-1  Spontaneously healed atopic dermatitis  GSE162054
# AD20_AAACGAACATGGCGCT-1  Spontaneously healed atopic dermatitis  GSE162054
# AD20_AAACGAATCACAGTGT-1  Spontaneously healed atopic dermatitis  GSE162054
# AD20_AAACGCTCAGGATGAC-1  Spontaneously healed atopic dermatitis  GSE162054
# ...                                                         ...        ...
# AD24_TTTCGATAGCATACTC-1  Spontaneously healed atopic dermatitis  GSE162054
# AD24_TTTGACTAGCATTTCG-1  Spontaneously healed atopic dermatitis  GSE162054
# AD24_TTTGACTAGTGAATAC-1  Spontaneously healed atopic dermatitis  GSE162054
# AD24_TTTGACTAGTTCATCG-1  Spontaneously healed atopic dermatitis  GSE162054
# AD24_TTTGATCAGCTTCTAG-1  Spontaneously healed atopic dermatitis  GSE162054
#
#                          easi_score severity
# barcodes
# AD20_AAACCCAGTGTGTTTG-1           0    clear
# AD20_AAACCCATCTCCCTAG-1           0    clear
# AD20_AAACGAACATGGCGCT-1           0    clear
# AD20_AAACGAATCACAGTGT-1           0    clear
# AD20_AAACGCTCAGGATGAC-1           0    clear
# ...                             ...      ...
# AD24_TTTCGATAGCATACTC-1           0    clear
# AD24_TTTGACTAGCATTTCG-1           0    clear
# AD24_TTTGACTAGTGAATAC-1           0    clear
# AD24_TTTGACTAGTTCATCG-1           0    clear
# AD24_TTTGATCAGCTTCTAG-1           0    clear
#
# [3598 rows x 7 columns]

# %%
adata.obs['condition'] = 'Spontaneously healed atopic dermatitis'
adata.obs
# Out:
#                         sample patient                tissue  \
# barcodes
# AD20_AAACCCAGTGTGTTTG-1   AD20    AD20  Skin Suction blister
# AD20_AAACCCATCTCCCTAG-1   AD20    AD20  Skin Suction blister
# AD20_AAACGAACATGGCGCT-1   AD20    AD20  Skin Suction blister
# AD20_AAACGAATCACAGTGT-1   AD20    AD20  Skin Suction blister
# AD20_AAACGCTCAGGATGAC-1   AD20    AD20  Skin Suction blister
# ...                        ...     ...                   ...
# AD24_TTTCGATAGCATACTC-1   AD24    AD24  Skin Suction blister
# AD24_TTTGACTAGCATTTCG-1   AD24    AD24  Skin Suction blister
# AD24_TTTGACTAGTGAATAC-1   AD24    AD24  Skin Suction blister
# AD24_TTTGACTAGTTCATCG-1   AD24    AD24  Skin Suction blister
# AD24_TTTGATCAGCTTCTAG-1   AD24    AD24  Skin Suction blister
#
#                                                       condition
# barcodes
# AD20_AAACCCAGTGTGTTTG-1  Spontaneously healed atopic dermatitis
# AD20_AAACCCATCTCCCTAG-1  Spontaneously healed atopic dermatitis
# AD20_AAACGAACATGGCGCT-1  Spontaneously healed atopic dermatitis
# AD20_AAACGAATCACAGTGT-1  Spontaneously healed atopic dermatitis
# AD20_AAACGCTCAGGATGAC-1  Spontaneously healed atopic dermatitis
# ...                                                         ...
# AD24_TTTCGATAGCATACTC-1  Spontaneously healed atopic dermatitis
# AD24_TTTGACTAGCATTTCG-1  Spontaneously healed atopic dermatitis
# AD24_TTTGACTAGTGAATAC-1  Spontaneously healed atopic dermatitis
# AD24_TTTGACTAGTTCATCG-1  Spontaneously healed atopic dermatitis
# AD24_TTTGATCAGCTTCTAG-1  Spontaneously healed atopic dermatitis
#
# [3598 rows x 4 columns]

# %%
adata.obs['batch'] = 'GSE162054'
adata.obs
# Out:
#                         sample patient                tissue  \
# barcodes
# AD20_AAACCCAGTGTGTTTG-1   AD20    AD20  Skin Suction blister
# AD20_AAACCCATCTCCCTAG-1   AD20    AD20  Skin Suction blister
# AD20_AAACGAACATGGCGCT-1   AD20    AD20  Skin Suction blister
# AD20_AAACGAATCACAGTGT-1   AD20    AD20  Skin Suction blister
# AD20_AAACGCTCAGGATGAC-1   AD20    AD20  Skin Suction blister
# ...                        ...     ...                   ...
# AD24_TTTCGATAGCATACTC-1   AD24    AD24  Skin Suction blister
# AD24_TTTGACTAGCATTTCG-1   AD24    AD24  Skin Suction blister
# AD24_TTTGACTAGTGAATAC-1   AD24    AD24  Skin Suction blister
# AD24_TTTGACTAGTTCATCG-1   AD24    AD24  Skin Suction blister
# AD24_TTTGATCAGCTTCTAG-1   AD24    AD24  Skin Suction blister
#
#                                                       condition      batch
# barcodes
# AD20_AAACCCAGTGTGTTTG-1  Spontaneously healed atopic dermatitis  GSE162054
# AD20_AAACCCATCTCCCTAG-1  Spontaneously healed atopic dermatitis  GSE162054
# AD20_AAACGAACATGGCGCT-1  Spontaneously healed atopic dermatitis  GSE162054
# AD20_AAACGAATCACAGTGT-1  Spontaneously healed atopic dermatitis  GSE162054
# AD20_AAACGCTCAGGATGAC-1  Spontaneously healed atopic dermatitis  GSE162054
# ...                                                         ...        ...
# AD24_TTTCGATAGCATACTC-1  Spontaneously healed atopic dermatitis  GSE162054
# AD24_TTTGACTAGCATTTCG-1  Spontaneously healed atopic dermatitis  GSE162054
# AD24_TTTGACTAGTGAATAC-1  Spontaneously healed atopic dermatitis  GSE162054
# AD24_TTTGACTAGTTCATCG-1  Spontaneously healed atopic dermatitis  GSE162054
# AD24_TTTGATCAGCTTCTAG-1  Spontaneously healed atopic dermatitis  GSE162054
#
# [3598 rows x 5 columns]

# %%
adata.obs
# Out:
#                         sample patient                tissue  \
# barcodes
# AD20_AAACCCAGTGTGTTTG-1   AD20    AD20  Skin Suction Blister
# AD20_AAACCCATCTCCCTAG-1   AD20    AD20  Skin Suction Blister
# AD20_AAACGAACATGGCGCT-1   AD20    AD20  Skin Suction Blister
# AD20_AAACGAATCACAGTGT-1   AD20    AD20  Skin Suction Blister
# AD20_AAACGCTCAGGATGAC-1   AD20    AD20  Skin Suction Blister
# ...                        ...     ...                   ...
# AD24_TTTCGATAGCATACTC-1   AD24    AD24  Skin Suction Blister
# AD24_TTTGACTAGCATTTCG-1   AD24    AD24  Skin Suction Blister
# AD24_TTTGACTAGTGAATAC-1   AD24    AD24  Skin Suction Blister
# AD24_TTTGACTAGTTCATCG-1   AD24    AD24  Skin Suction Blister
# AD24_TTTGATCAGCTTCTAG-1   AD24    AD24  Skin Suction Blister
#
#                                                       condition      batch  \
# barcodes
# AD20_AAACCCAGTGTGTTTG-1  Spontaneously healed atopic dermatitis  GSE162054
# AD20_AAACCCATCTCCCTAG-1  Spontaneously healed atopic dermatitis  GSE162054
# AD20_AAACGAACATGGCGCT-1  Spontaneously healed atopic dermatitis  GSE162054
# AD20_AAACGAATCACAGTGT-1  Spontaneously healed atopic dermatitis  GSE162054
# AD20_AAACGCTCAGGATGAC-1  Spontaneously healed atopic dermatitis  GSE162054
# ...                                                         ...        ...
# AD24_TTTCGATAGCATACTC-1  Spontaneously healed atopic dermatitis  GSE162054
# AD24_TTTGACTAGCATTTCG-1  Spontaneously healed atopic dermatitis  GSE162054
# AD24_TTTGACTAGTGAATAC-1  Spontaneously healed atopic dermatitis  GSE162054
# AD24_TTTGACTAGTTCATCG-1  Spontaneously healed atopic dermatitis  GSE162054
# AD24_TTTGATCAGCTTCTAG-1  Spontaneously healed atopic dermatitis  GSE162054
#
#                          easi_score severity
# barcodes
# AD20_AAACCCAGTGTGTTTG-1           0    clear
# AD20_AAACCCATCTCCCTAG-1           0    clear
# AD20_AAACGAACATGGCGCT-1           0    clear
# AD20_AAACGAATCACAGTGT-1           0    clear
# AD20_AAACGCTCAGGATGAC-1           0    clear
# ...                             ...      ...
# AD24_TTTCGATAGCATACTC-1           0    clear
# AD24_TTTGACTAGCATTTCG-1           0    clear
# AD24_TTTGACTAGTGAATAC-1           0    clear
# AD24_TTTGACTAGTTCATCG-1           0    clear
# AD24_TTTGATCAGCTTCTAG-1           0    clear
#
# [3598 rows x 7 columns]

# %%
adata.write('/nfs/data/COST_IBD/data/atopic_dermatitis/anndata/rindler.h5ad')

# %%
adata = sc.read('/nfs/data/COST_IBD/data/atopic_dermatitis/anndata/rindler.h5ad')

# %%
adata.obs['sample'].unique()
# Out:
# ['AD20', 'AD25', 'AD21', 'AD24']
# Categories (4, object): ['AD20', 'AD21', 'AD24', 'AD25']

# %%
easi_dict = {
    'AD20': 0,
    'AD21': 0,
    'AD25': 0,
    'AD24': 0,
}
adata.obs['easi_score'] = adata.obs['sample'].map(easi_dict)
adata.obs
# Out:
#                         sample patient                tissue  \
# barcodes
# AD20_AAACCCAGTGTGTTTG-1   AD20    AD20  Skin Suction blister
# AD20_AAACCCATCTCCCTAG-1   AD20    AD20  Skin Suction blister
# AD20_AAACGAACATGGCGCT-1   AD20    AD20  Skin Suction blister
# AD20_AAACGAATCACAGTGT-1   AD20    AD20  Skin Suction blister
# AD20_AAACGCTCAGGATGAC-1   AD20    AD20  Skin Suction blister
# ...                        ...     ...                   ...
# AD24_TTTCGATAGCATACTC-1   AD24    AD24  Skin Suction blister
# AD24_TTTGACTAGCATTTCG-1   AD24    AD24  Skin Suction blister
# AD24_TTTGACTAGTGAATAC-1   AD24    AD24  Skin Suction blister
# AD24_TTTGACTAGTTCATCG-1   AD24    AD24  Skin Suction blister
# AD24_TTTGATCAGCTTCTAG-1   AD24    AD24  Skin Suction blister
#
#                                                       condition      batch  \
# barcodes
# AD20_AAACCCAGTGTGTTTG-1  Spontaneously healed atopic dermatitis  GSE162054
# AD20_AAACCCATCTCCCTAG-1  Spontaneously healed atopic dermatitis  GSE162054
# AD20_AAACGAACATGGCGCT-1  Spontaneously healed atopic dermatitis  GSE162054
# AD20_AAACGAATCACAGTGT-1  Spontaneously healed atopic dermatitis  GSE162054
# AD20_AAACGCTCAGGATGAC-1  Spontaneously healed atopic dermatitis  GSE162054
# ...                                                         ...        ...
# AD24_TTTCGATAGCATACTC-1  Spontaneously healed atopic dermatitis  GSE162054
# AD24_TTTGACTAGCATTTCG-1  Spontaneously healed atopic dermatitis  GSE162054
# AD24_TTTGACTAGTGAATAC-1  Spontaneously healed atopic dermatitis  GSE162054
# AD24_TTTGACTAGTTCATCG-1  Spontaneously healed atopic dermatitis  GSE162054
# AD24_TTTGATCAGCTTCTAG-1  Spontaneously healed atopic dermatitis  GSE162054
#
#                          easi_score
# barcodes
# AD20_AAACCCAGTGTGTTTG-1           0
# AD20_AAACCCATCTCCCTAG-1           0
# AD20_AAACGAACATGGCGCT-1           0
# AD20_AAACGAATCACAGTGT-1           0
# AD20_AAACGCTCAGGATGAC-1           0
# ...                             ...
# AD24_TTTCGATAGCATACTC-1           0
# AD24_TTTGACTAGCATTTCG-1           0
# AD24_TTTGACTAGTGAATAC-1           0
# AD24_TTTGACTAGTTCATCG-1           0
# AD24_TTTGATCAGCTTCTAG-1           0
#
# [3598 rows x 6 columns]

# %%
def assign_severity(easi_score):
    if pd.isna(easi_score):
        return None
    elif easi_score in [0, 1]:
        return 'clear'
    elif easi_score in [1.1, 7]:
        return 'mild'
    elif easi_score in [7.1, 21]:
        return 'moderate'
    elif easi_score in [21.1, 50]:
        return 'severe'
    else:
        return 'unknown'

adata.obs['severity'] = adata.obs['easi_score'].apply(assign_severity).values
adata.obs
# Out:
#                         sample patient                tissue  \
# barcodes
# AD20_AAACCCAGTGTGTTTG-1   AD20    AD20  Skin Suction blister
# AD20_AAACCCATCTCCCTAG-1   AD20    AD20  Skin Suction blister
# AD20_AAACGAACATGGCGCT-1   AD20    AD20  Skin Suction blister
# AD20_AAACGAATCACAGTGT-1   AD20    AD20  Skin Suction blister
# AD20_AAACGCTCAGGATGAC-1   AD20    AD20  Skin Suction blister
# ...                        ...     ...                   ...
# AD24_TTTCGATAGCATACTC-1   AD24    AD24  Skin Suction blister
# AD24_TTTGACTAGCATTTCG-1   AD24    AD24  Skin Suction blister
# AD24_TTTGACTAGTGAATAC-1   AD24    AD24  Skin Suction blister
# AD24_TTTGACTAGTTCATCG-1   AD24    AD24  Skin Suction blister
# AD24_TTTGATCAGCTTCTAG-1   AD24    AD24  Skin Suction blister
#
#                                                       condition      batch  \
# barcodes
# AD20_AAACCCAGTGTGTTTG-1  Spontaneously healed atopic dermatitis  GSE162054
# AD20_AAACCCATCTCCCTAG-1  Spontaneously healed atopic dermatitis  GSE162054
# AD20_AAACGAACATGGCGCT-1  Spontaneously healed atopic dermatitis  GSE162054
# AD20_AAACGAATCACAGTGT-1  Spontaneously healed atopic dermatitis  GSE162054
# AD20_AAACGCTCAGGATGAC-1  Spontaneously healed atopic dermatitis  GSE162054
# ...                                                         ...        ...
# AD24_TTTCGATAGCATACTC-1  Spontaneously healed atopic dermatitis  GSE162054
# AD24_TTTGACTAGCATTTCG-1  Spontaneously healed atopic dermatitis  GSE162054
# AD24_TTTGACTAGTGAATAC-1  Spontaneously healed atopic dermatitis  GSE162054
# AD24_TTTGACTAGTTCATCG-1  Spontaneously healed atopic dermatitis  GSE162054
# AD24_TTTGATCAGCTTCTAG-1  Spontaneously healed atopic dermatitis  GSE162054
#
#                          easi_score severity
# barcodes
# AD20_AAACCCAGTGTGTTTG-1           0    clear
# AD20_AAACCCATCTCCCTAG-1           0    clear
# AD20_AAACGAACATGGCGCT-1           0    clear
# AD20_AAACGAATCACAGTGT-1           0    clear
# AD20_AAACGCTCAGGATGAC-1           0    clear
# ...                             ...      ...
# AD24_TTTCGATAGCATACTC-1           0    clear
# AD24_TTTGACTAGCATTTCG-1           0    clear
# AD24_TTTGACTAGTGAATAC-1           0    clear
# AD24_TTTGACTAGTTCATCG-1           0    clear
# AD24_TTTGATCAGCTTCTAG-1           0    clear
#
# [3598 rows x 7 columns]

# %%
adata = sc.read('/nfs/data/COST_IBD/data/atopic_dermatitis/anndata/filtered/rindler_filtered.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 1532 × 33538
#     obs: 'batch', 'cell_type', 'condition', 'sex', 'patient', 'tissue', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb'
#     var: 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'

# %%
adata.obs['condition'].unique()
# Out:
# ['Spontaneously healed atopic dermatitis']
# Categories (1, object): ['Spontaneously healed atopic dermatitis']

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 3598 × 33538
#     obs: 'sample', 'patient', 'tissue', 'condition', 'batch', 'easi_score', 'severity'

# %%
adata_filtered = sc.read('/nfs/data/COST_IBD/versions/AD/03_00_00/data/rindler.h5ad')
adata_filtered
# Out:
# AnnData object with n_obs × n_vars = 3598 × 33538
#     obs: 'sample', 'patient', 'tissue', 'condition', 'batch', 'easi_score', 'severity'
